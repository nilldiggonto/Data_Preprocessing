# %%
#lib

# %%
import pandas as pd

# %%
data = pd.read_csv('files/titanic.csv')

# %%
data.head(5)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
data = pd.read_csv('files/titanic.csv',index_col='pclass')

# %%
data.head()
# Out:
#         survived     sex   age  sibsp  parch     fare embarked deck
# pclass
# 3              0    male  22.0      1      0   7.2500        S  NaN
# 1              1  female  38.0      1      0  71.2833        C    C
# 3              1  female  26.0      0      0   7.9250        S  NaN
# 1              1  female  35.0      1      0  53.1000        S    C
# 3              0    male  35.0      0      0   8.0500        S  NaN

# %%
data = pd.read_csv('files/titanic.csv',header = 0)

# %%
data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
data = pd.read_csv('files/titanic.csv', header=0,names=['Outlast','Seat','Gender','Age','Siblings','Family','Rate','Embarked','Deck'])

# %%
data.head()
# Out:
#    Outlast  Seat  Gender   Age  Siblings  Family     Rate Embarked Deck
# 0        0     3    male  22.0         1       0   7.2500        S  NaN
# 1        1     1  female  38.0         1       0  71.2833        C    C
# 2        1     3  female  26.0         0       0   7.9250        S  NaN
# 3        1     1  female  35.0         1       0  53.1000        S    C
# 4        0     3    male  35.0         0       0   8.0500        S  NaN

# %%
data = pd.read_csv('files/titanic.csv',header=0, index_col='pclass', usecols= ['pclass','survived','age','sex'])

# %%
data.head()
# Out:
#         survived     sex   age
# pclass
# 3              0    male  22.0
# 1              1  female  38.0
# 3              1  female  26.0
# 1              1  female  35.0
# 3              0    male  35.0
