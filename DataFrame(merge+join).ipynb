# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
data2004 = pd.read_csv('files/men2004.csv')

# %%
data2004
# Out:
#                        Athlete  Medals
# 0              PHELPS, Michael       8
# 1                  THORPE, Ian       4
# 2             SCHOEMAN, Roland       3
# 3               PEIRSOL, Aaron       3
# 4                 CROCKER, Ian       3
# 5             KITAJIMA, Kosuke       3
# 6              HANSEN, Brendan       3
# 7   VAN DEN HOOGENBAND, Pieter       3
# 8               HACKETT, Grant       3
# 9               MORITA, Tomomi       2
# 10                LEZAK, Jason       2
# 11               ROGAN, Markus       2
# 12               KELLER, Klete       2
# 13              HALL, Gary Jr.       2
# 14                LOCHTE, Ryan       2
# 15                WALKER, Neil       2
# 16           YAMAMOTO, Takashi       2
# 17          SPRENGER, Nicholas       1
# 18          OKUMURA, Yoshihiro       1
# 19              PARRY, Stephen       1
# 20               PEARSON, Todd       1
# 21              ZASTROW, Mitja       1
# 22          PELLICIARI, Matteo       1
# ...

# %%
data2008 = pd.read_csv('files/men2008.csv')

# %%
data2008
# Out:
#                      Athlete  Medals
# 0            PHELPS, Michael       8
# 1               LOCHTE, Ryan       4
# 2             BERNARD, Alain       3
# 3            SULLIVAN, Eamon       3
# 4        LAUTERSTEIN, Andrew       3
# 5              GREVERS, Matt       3
# 6               LEZAK, Jason       3
# 7               CSEH, Laszlo       3
# 8           KITAJIMA, Kosuke       3
# 9             PEIRSOL, Aaron       3
# 10          RICKARD, Brenton       2
# 11           LEVEAUX, Amaury       2
# 12            HACKETT, Grant       2
# 13          STOECKEL, Hayden       2
# 14             TARGETT, Matt       2
# 15           DUBOSCQ, Hugues       2
# 16         VANDERKAAY, Peter       2
# 17             PARK, Taehwan       2
# 18        CIELO FILHO, Cesar       2
# 19        VYATCHANIN, Arkady       2
# 20             BRODIE, Leith       2
# 21       WEBER-GALE, Garrett       2
# 22           MURPHY, Patrick       2
# 23       OEN, Alexander Dale       1
# ...

# %%
#combining data2004 and data2008

# %%
data2004.append(data2008,ignore_index=True)
# Out:
#                         Athlete  Medals
# 0               PHELPS, Michael       8
# 1                   THORPE, Ian       4
# 2              SCHOEMAN, Roland       3
# 3                PEIRSOL, Aaron       3
# 4                  CROCKER, Ian       3
# 5              KITAJIMA, Kosuke       3
# 6               HANSEN, Brendan       3
# 7    VAN DEN HOOGENBAND, Pieter       3
# 8                HACKETT, Grant       3
# 9                MORITA, Tomomi       2
# 10                 LEZAK, Jason       2
# 11                ROGAN, Markus       2
# 12                KELLER, Klete       2
# 13               HALL, Gary Jr.       2
# 14                 LOCHTE, Ryan       2
# 15                 WALKER, Neil       2
# 16            YAMAMOTO, Takashi       2
# 17           SPRENGER, Nicholas       1
# 18           OKUMURA, Yoshihiro       1
# 19               PARRY, Stephen       1
# 20                PEARSON, Todd       1
# 21               ZASTROW, Mitja       1
# ...

# %%
#concat

# %%
men_data =pd.concat([data2004,data2008],ignore_index=False,keys=[2004,2008], names=['Year'])

# %%
men_data
# Out:
#                             Athlete  Medals
# Year
# 2004 0              PHELPS, Michael       8
#      1                  THORPE, Ian       4
#      2             SCHOEMAN, Roland       3
#      3               PEIRSOL, Aaron       3
#      4                 CROCKER, Ian       3
#      5             KITAJIMA, Kosuke       3
#      6              HANSEN, Brendan       3
#      7   VAN DEN HOOGENBAND, Pieter       3
#      8               HACKETT, Grant       3
#      9               MORITA, Tomomi       2
#      10                LEZAK, Jason       2
#      11               ROGAN, Markus       2
#      12               KELLER, Klete       2
#      13              HALL, Gary Jr.       2
#      14                LOCHTE, Ryan       2
#      15                WALKER, Neil       2
#      16           YAMAMOTO, Takashi       2
#      17          SPRENGER, Nicholas       1
#      18          OKUMURA, Yoshihiro       1
#      19              PARRY, Stephen       1
# ...

# %%
men_data.reset_index()
# Out:
#      Year  level_1                     Athlete  Medals
# 0    2004        0             PHELPS, Michael       8
# 1    2004        1                 THORPE, Ian       4
# 2    2004        2            SCHOEMAN, Roland       3
# 3    2004        3              PEIRSOL, Aaron       3
# 4    2004        4                CROCKER, Ian       3
# 5    2004        5            KITAJIMA, Kosuke       3
# 6    2004        6             HANSEN, Brendan       3
# 7    2004        7  VAN DEN HOOGENBAND, Pieter       3
# 8    2004        8              HACKETT, Grant       3
# 9    2004        9              MORITA, Tomomi       2
# 10   2004       10                LEZAK, Jason       2
# 11   2004       11               ROGAN, Markus       2
# 12   2004       12               KELLER, Klete       2
# 13   2004       13              HALL, Gary Jr.       2
# 14   2004       14                LOCHTE, Ryan       2
# 15   2004       15                WALKER, Neil       2
# ...

# %%
men_data.reset_index().drop(columns='level_1')
# Out:
#      Year                     Athlete  Medals
# 0    2004             PHELPS, Michael       8
# 1    2004                 THORPE, Ian       4
# 2    2004            SCHOEMAN, Roland       3
# 3    2004              PEIRSOL, Aaron       3
# 4    2004                CROCKER, Ian       3
# 5    2004            KITAJIMA, Kosuke       3
# 6    2004             HANSEN, Brendan       3
# 7    2004  VAN DEN HOOGENBAND, Pieter       3
# 8    2004              HACKETT, Grant       3
# 9    2004              MORITA, Tomomi       2
# 10   2004                LEZAK, Jason       2
# 11   2004               ROGAN, Markus       2
# 12   2004               KELLER, Klete       2
# 13   2004              HALL, Gary Jr.       2
# 14   2004                LOCHTE, Ryan       2
# 15   2004                WALKER, Neil       2
# 16   2004           YAMAMOTO, Takashi       2
# 17   2004          SPRENGER, Nicholas       1
# 18   2004          OKUMURA, Yoshihiro       1
# ...

# %%
###########

# %%
data2004.head()
# Out:
#             Athlete  Medals
# 0   PHELPS, Michael       8
# 1       THORPE, Ian       4
# 2  SCHOEMAN, Roland       3
# 3    PEIRSOL, Aaron       3
# 4      CROCKER, Ian       3

# %%
data2008.head()
# Out:
#                Athlete  Medals
# 0      PHELPS, Michael       8
# 1         LOCHTE, Ryan       4
# 2       BERNARD, Alain       3
# 3      SULLIVAN, Eamon       3
# 4  LAUTERSTEIN, Andrew       3

# %%
data2004.columns = ['Name','Medals']

# %%
data2004['Success'] = 'Yes'

# %%
data2004.head()
# Out:
#                Name  Medals Success
# 0   PHELPS, Michael       8     Yes
# 1       THORPE, Ian       4     Yes
# 2  SCHOEMAN, Roland       3     Yes
# 3    PEIRSOL, Aaron       3     Yes
# 4      CROCKER, Ian       3     Yes

# %%
##concat

# %%
pd.concat([data2004,data2008],keys=[2004,2008],names=['Year'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
#                           Athlete  Medals                        Name Success
# Year
# 2004 0                        NaN       8             PHELPS, Michael     Yes
#      1                        NaN       4                 THORPE, Ian     Yes
#      2                        NaN       3            SCHOEMAN, Roland     Yes
#      3                        NaN       3              PEIRSOL, Aaron     Yes
#      4                        NaN       3                CROCKER, Ian     Yes
#      5                        NaN       3            KITAJIMA, Kosuke     Yes
# ...

# %%
##

# %%
data2004.drop(labels=['Success'],axis=1,inplace=True)

# %%
data2004.head()
# Out:
#                Name  Medals
# 0   PHELPS, Michael       8
# 1       THORPE, Ian       4
# 2  SCHOEMAN, Roland       3
# 3    PEIRSOL, Aaron       3
# 4      CROCKER, Ian       3

# %%
data2008.columns
# Out:
# Index(['Athlete', 'Medals'], dtype='object')

# %%
data2004.columns
# Out:
# Index(['Name', 'Medals'], dtype='object')

# %%
data2008.columns = data2004.columns

# %%
data2008.head()
# Out:
#                   Name  Medals
# 0      PHELPS, Michael       8
# 1         LOCHTE, Ryan       4
# 2       BERNARD, Alain       3
# 3      SULLIVAN, Eamon       3
# 4  LAUTERSTEIN, Andrew       3

# %%
data2004.head()
# Out:
#                Name  Medals
# 0   PHELPS, Michael       8
# 1       THORPE, Ian       4
# 2  SCHOEMAN, Roland       3
# 3    PEIRSOL, Aaron       3
# 4      CROCKER, Ian       3

# %%
pd.concat([data2004,data2008],keys=[2004,2008],names=['Year'])
# Out:
#                                Name  Medals
# Year
# 2004 0              PHELPS, Michael       8
#      1                  THORPE, Ian       4
#      2             SCHOEMAN, Roland       3
#      3               PEIRSOL, Aaron       3
#      4                 CROCKER, Ian       3
#      5             KITAJIMA, Kosuke       3
#      6              HANSEN, Brendan       3
#      7   VAN DEN HOOGENBAND, Pieter       3
#      8               HACKETT, Grant       3
#      9               MORITA, Tomomi       2
#      10                LEZAK, Jason       2
#      11               ROGAN, Markus       2
#      12               KELLER, Klete       2
#      13              HALL, Gary Jr.       2
#      14                LOCHTE, Ryan       2
#      15                WALKER, Neil       2
#      16           YAMAMOTO, Takashi       2
#      17          SPRENGER, Nicholas       1
#      18          OKUMURA, Yoshihiro       1
#      19              PARRY, Stephen       1
# ...

# %%
###########

# %%
##########

# %%
data2004 = pd.read_csv('files/men2004.csv',index_col='Athlete')
data2008 = pd.read_csv('files/men2008.csv',index_col='Athlete')

# %%
data2004.head()
# Out:
#                   Medals
# Athlete
# PHELPS, Michael        8
# THORPE, Ian            4
# SCHOEMAN, Roland       3
# PEIRSOL, Aaron         3
# CROCKER, Ian           3

# %%
data2008.head()
# Out:
#                      Medals
# Athlete
# PHELPS, Michael           8
# LOCHTE, Ryan              4
# BERNARD, Alain            3
# SULLIVAN, Eamon           3
# LAUTERSTEIN, Andrew       3

# %%
pd.concat([data2004,data2008],ignore_index=False,keys=[2004,2008])
# Out:
#                                  Medals
#      Athlete
# 2004 PHELPS, Michael                  8
#      THORPE, Ian                      4
#      SCHOEMAN, Roland                 3
#      PEIRSOL, Aaron                   3
#      CROCKER, Ian                     3
#      KITAJIMA, Kosuke                 3
#      HANSEN, Brendan                  3
#      VAN DEN HOOGENBAND, Pieter       3
#      HACKETT, Grant                   3
#      MORITA, Tomomi                   2
#      LEZAK, Jason                     2
#      ROGAN, Markus                    2
#      KELLER, Klete                    2
#      HALL, Gary Jr.                   2
#      LOCHTE, Ryan                     2
#      WALKER, Neil                     2
#      YAMAMOTO, Takashi                2
#      SPRENGER, Nicholas               1
#      OKUMURA, Yoshihiro               1
#      PARRY, Stephen                   1
#      PEARSON, Todd                    1
#      ZASTROW, Mitja                   1
# ...
