# %%
import pandas as pd

# %%
#clean data

# %%
data = pd.read_csv('files/titanic_imp.csv')

# %%
pd.options.display.max_rows= 10

# %%
data.head()
# Out:
#   Survived  Class  Gender   Age  SipSp  ParCh      Fare Emb Deck
# 0        0      3    male  22.0      1      0     $7.25   S  NaN
# 1        1      1  female  38.0      1      0  $71.2833   C    C
# 2        1      3  female  26.0      0      0    $7.925   S  NaN
# 3        1      1  female  35.0      1      0     $53.1   S    C
# 4        0      3    male  35.0      0      0     $8.05   S  NaN

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 894 entries, 0 to 893
# Data columns (total 9 columns):
# Survived    894 non-null object
# Class       894 non-null int64
# Gender      894 non-null object
# Age         758 non-null object
# SipSp       894 non-null int64
# ParCh       894 non-null int64
# Fare        894 non-null object
# Emb         892 non-null object
# Deck        203 non-null object
# dtypes: int64(3), object(6)
# memory usage: 62.9+ KB

# %%
#data['Survive','age','fare'] column should be an int64 and age float , fare float

# %%
data.describe()
# Out:
#             Class       SipSp       ParCh
# count  894.000000  894.000000  894.000000
# mean     2.309843    0.522371    0.381432
# std      0.835370    1.101283    0.805171
# min      1.000000    0.000000    0.000000
# 25%      2.000000    0.000000    0.000000
# 50%      3.000000    0.000000    0.000000
# 75%      3.000000    1.000000    0.000000
# max      3.000000    8.000000    6.000000

# %%
#selecting non-numeric

# %%
data[['Survived','Gender','Age','Fare','Emb','Deck']].describe()
# Out:
#        Survived Gender           Age   Fare  Emb Deck
# count       894    894           758    894  892  203
# unique        4      2            92    248    3    7
# top           0   male  Missing Data  $8.05    S    C
# freq        551    580            41     43  647   59

# %%
data['Survived'].unique()
# Out:
# array(['0', '1', 'yes', 'no'], dtype=object)

# %%
data['Survived'].value_counts()
# Out:
# 0      551
# 1      341
# yes      1
# no       1
# Name: Survived, dtype: int64

# %%
#data['Survived'] should only (0,1) or (yes,no)

# %%
data['Survived'].replace(to_replace=['yes','no'],value=[1,0],inplace=True)

# %%
data['Survived'].value_counts()
# Out:
# 0    551
# 1    341
# 1      1
# 0      1
# Name: Survived, dtype: int64

# %%
#first (0,1) still refers as object dtype and last(1,0) as int64 dtype

# %%
new_data = pd.read_csv('files/summer_imp.csv')

# %%
new_data.head()
# Out:
#    Year    City     Sport Discipline          Athlete Name Country Gender  \
# 0  1896  Athens  Aquatics   Swimming        HAJOS, Alfred      HUN    Men
# 1  1896  Athens  Aquatics   Swimming     HERSCHMANN, Otto      AUT    Men
# 2  1896  Athens  Aquatics   Swimming    DRIVAS, Dimitrios      GRE    Men
# 3  1896  Athens  Aquatics   Swimming   Malokinis, Ioannis      GRE    Men
# 4  1896  Athens  Aquatics   Swimming   Chasapis, Spiridon      GRE    Men
#
#                         Event       Medal
# 0              100M Freestyle  Gold Medal
# 1              100M Freestyle      Silver
# 2  100M Freestyle For Sailors      Bronze
# 3  100M Freestyle For Sailors  Gold Medal
# 4  100M Freestyle For Sailors      Silver

# %%
new_data.tail()
# Out:
#        Year    City      Sport           Discipline  \
# 31165  2012  London  Wrestling  Wrestling Freestyle
# 31166  2012  London  Wrestling  Wrestling Freestyle
# 31167  2012  London  Wrestling  Wrestling Freestyle
# 31168  2012  London  Wrestling  Wrestling Freestyle
# 31169  2012  London  Wrestling  Wrestling Freestyle
#
#                       Athlete Name Country Gender     Event   Medal
# 31165          JANIKOWSKI, Damian      POL    Men  Wg 84 KG  Bronze
# 31166   REZAEI, Ghasem Gholamreza      IRI    Men  Wg 96 KG    Gold
# 31167              TOTROV, Rustam      RUS    Men  Wg 96 KG  Silver
# 31168           ALEKSANYAN, Artur      ARM    Men  Wg 96 KG  Bronze
# 31169              LIDBERG, Jimmy      SWE    Men  Wg 96 KG  Bronze

# %%
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31170 entries, 0 to 31169
# Data columns (total 9 columns):
# Year            31170 non-null int64
# City            31170 non-null object
# Sport           31170 non-null object
# Discipline      31170 non-null object
# Athlete Name    31170 non-null object
# Country         31166 non-null object
# Gender          31170 non-null object
# Event           31170 non-null object
# Medal           31170 non-null object
# dtypes: int64(1), object(8)
# memory usage: 2.1+ MB

# %%
#Athlete Name column is not a robust name

# %%
#rename

# %%
new_data.rename(columns= {'Athlete Name':'Athlete_name'},inplace=True)

# %%
new_data.head()
# Out:
#    Year    City     Sport Discipline          Athlete_name Country Gender  \
# 0  1896  Athens  Aquatics   Swimming        HAJOS, Alfred      HUN    Men
# 1  1896  Athens  Aquatics   Swimming     HERSCHMANN, Otto      AUT    Men
# 2  1896  Athens  Aquatics   Swimming    DRIVAS, Dimitrios      GRE    Men
# 3  1896  Athens  Aquatics   Swimming   Malokinis, Ioannis      GRE    Men
# 4  1896  Athens  Aquatics   Swimming   Chasapis, Spiridon      GRE    Men
#
#                         Event       Medal
# 0              100M Freestyle  Gold Medal
# 1              100M Freestyle      Silver
# 2  100M Freestyle For Sailors      Bronze
# 3  100M Freestyle For Sailors  Gold Medal
# 4  100M Freestyle For Sailors      Silver

# %%
new_data['Medal'].head(20)
# Out:
# 0     Gold Medal
# 1         Silver
# 2         Bronze
# 3     Gold Medal
# 4         Silver
#          ...
# 15          Gold
# 16        Silver
# 17        Bronze
# 18          Gold
# 19        Silver
# Name: Medal, Length: 20, dtype: object

# %%
#for first rows some values are ['Gold Medal'] but later its just ['Gold']

# %%
new_data['Medal'].unique()
# Out:
# array(['Gold Medal', 'Silver', 'Bronze', 'Gold'], dtype=object)

# %%
#['Gold Medal'] should be ['Gold'] #inconsistency

# %%
new_data['Medal'].value_counts()
# Out:
# Gold          10483
# Bronze        10372
# Silver        10311
# Gold Medal        4
# Name: Medal, dtype: int64

# %%
new_data['Medal'].replace(to_replace ='Gold Medal',value='Gold',inplace=True)

# %%
new_data['Medal'].value_counts()
# Out:
# Gold      10487
# Bronze    10372
# Silver    10311
# Name: Medal, dtype: int64

# %%
new_data.iloc[:,1:].describe() #non numeric describe
# Out:
#           City     Sport Discipline       Athlete_name Country Gender  \
# count    31170     31170      31170              31170   31166  31170
# unique      22        43         67              22763     147      2
# top     London  Aquatics  Athletics   PHELPS, Michael      USA    Men
# freq      3567      4170       3639                 22    4586  22751
#
#            Event  Medal
# count      31170  31170
# unique       666      3
# top     Football   Gold
# freq        1497  10487

# %%
#string validation

# %%
data['Fare']
# Out:
# 0         $7.25
# 1      $71.2833
# 2        $7.925
# 3         $53.1
# 4         $8.05
#          ...
# 889       $30.0
# 890       $7.75
# 891       $10.5
# 892       $14.4
# 893     $7.8958
# Name: Fare, Length: 894, dtype: object

# %%
#it has dtype object should be float type

# %%
# the [$] sign is the main reason for it

# %%
data['Fare']=data['Fare'].str.replace('$','')

# %%
data['Fare'].head()
# Out:
# 0       7.25
# 1    71.2833
# 2      7.925
# 3       53.1
# 4       8.05
# Name: Fare, dtype: object

# %%
#dtype is still object to make it numeric

# %%
pd.to_numeric(data['Fare'])
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 889    30.0000
# 890     7.7500
# 891    10.5000
# 892    14.4000
# 893     7.8958
# Name: Fare, Length: 894, dtype: float64

# %%
###

# %%
new_data.head()
# Out:
#    Year    City     Sport Discipline          Athlete_name Country Gender  \
# 0  1896  Athens  Aquatics   Swimming        HAJOS, Alfred      HUN    Men
# 1  1896  Athens  Aquatics   Swimming     HERSCHMANN, Otto      AUT    Men
# 2  1896  Athens  Aquatics   Swimming    DRIVAS, Dimitrios      GRE    Men
# 3  1896  Athens  Aquatics   Swimming   Malokinis, Ioannis      GRE    Men
# 4  1896  Athens  Aquatics   Swimming   Chasapis, Spiridon      GRE    Men
#
#                         Event   Medal
# 0              100M Freestyle    Gold
# 1              100M Freestyle  Silver
# 2  100M Freestyle For Sailors  Bronze
# 3  100M Freestyle For Sailors    Gold
# 4  100M Freestyle For Sailors  Silver

# %%
pd.options.display.max_rows= 20
new_data['Athlete_name']
# Out:
# 0                        HAJOS, Alfred
# 1                     HERSCHMANN, Otto
# 2                    DRIVAS, Dimitrios
# 3                   Malokinis, Ioannis
# 4                   Chasapis, Spiridon
# 5                Chorophas, Efstathios
# 6                        Hajos, Alfred
# 7                     Andreou, Joannis
# 8                Chorophas, Efstathios
# 9                        Neumann, Paul
#                       ...
# 31160                    AHMADOV, Emin
# 31161             KAZAKEVIC, Aleksandr
# 31162                    KHUGAEV, Alan
# 31163     EBRAHIM, Karam Mohamed Gaber
# 31164                  GAJIYEV, Danyal
# 31165               JANIKOWSKI, Damian
# 31166        REZAEI, Ghasem Gholamreza
# 31167                   TOTROV, Rustam
# 31168                ALEKSANYAN, Artur
# 31169                   LIDBERG, Jimmy
# Name: Athlete_name, Length: 31170, dtype: object

# %%
#string consistency failed as some of the name has all capital letter and some of them are not

# %%
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31170 entries, 0 to 31169
# Data columns (total 9 columns):
# Year            31170 non-null int64
# City            31170 non-null object
# Sport           31170 non-null object
# Discipline      31170 non-null object
# Athlete_name    31170 non-null object
# Country         31166 non-null object
# Gender          31170 non-null object
# Event           31170 non-null object
# Medal           31170 non-null object
# dtypes: int64(1), object(8)
# memory usage: 2.1+ MB

# %%
new_data['Athlete_name'] = new_data['Athlete_name'].str.title() #str.upper()  str.lower()

# %%
new_data['Athlete_name']
# Out:
# 0                        Hajos, Alfred
# 1                     Herschmann, Otto
# 2                    Drivas, Dimitrios
# 3                   Malokinis, Ioannis
# 4                   Chasapis, Spiridon
# 5                Chorophas, Efstathios
# 6                        Hajos, Alfred
# 7                     Andreou, Joannis
# 8                Chorophas, Efstathios
# 9                        Neumann, Paul
#                       ...
# 31160                    Ahmadov, Emin
# 31161             Kazakevic, Aleksandr
# 31162                    Khugaev, Alan
# 31163     Ebrahim, Karam Mohamed Gaber
# 31164                  Gajiyev, Danyal
# 31165               Janikowski, Damian
# 31166        Rezaei, Ghasem Gholamreza
# 31167                   Totrov, Rustam
# 31168                Aleksanyan, Artur
# 31169                   Lidberg, Jimmy
# Name: Athlete_name, Length: 31170, dtype: object

# %%
#filter column of "Hajos, Alfred"

# %%
new_data.loc[new_data['Athlete_name']== 'Hajos, Alfred']
# Out:
# Empty DataFrame
# Columns: [Year, City, Sport, Discipline, Athlete_name, Country, Gender, Event, Medal]
# Index: []

# %%
#most possible reason is there is some whitespace

# %%
new_data.iloc[0,4]
# Out:
# ' Hajos, Alfred '

# %%
#there is some space before and after ' Hajos, Alfred '

# %%
#str.contain method can be useful

# %%
new_data.loc[new_data['Athlete_name'].str.contains('Hajos, Alfred')]
# Out:
#    Year    City     Sport Discipline     Athlete_name Country Gender  \
# 0  1896  Athens  Aquatics   Swimming   Hajos, Alfred      HUN    Men
# 6  1896  Athens  Aquatics   Swimming   Hajos, Alfred      HUN    Men
#
#              Event Medal
# 0   100M Freestyle  Gold
# 6  1200M Freestyle  Gold

# %%
#but best is removing space

# %%
new_data['Athlete_name'] = new_data['Athlete_name'].str.strip() #lstrip()  #rstrip()

# %%
#now filter

# %%
new_data.loc[new_data['Athlete_name']== 'Hajos, Alfred']
# Out:
#    Year    City     Sport Discipline   Athlete_name Country Gender  \
# 0  1896  Athens  Aquatics   Swimming  Hajos, Alfred     HUN    Men
# 6  1896  Athens  Aquatics   Swimming  Hajos, Alfred     HUN    Men
#
#              Event Medal
# 0   100M Freestyle  Gold
# 6  1200M Freestyle  Gold

# %%
new_data.loc[new_data['Athlete_name']=='Phelps, Michael']
# Out:
#        Year     City     Sport Discipline     Athlete_name Country Gender  \
# 25229  2004   Athens  Aquatics   Swimming  Phelps, Michael     USA    Men
# 25257  2004   Athens  Aquatics   Swimming  Phelps, Michael     USA    Men
# 25262  2004   Athens  Aquatics   Swimming  Phelps, Michael     USA    Men
# 25269  2004   Athens  Aquatics   Swimming  Phelps, Michael     USA    Men
# 25281  2004   Athens  Aquatics   Swimming  Phelps, Michael     USA    Men
# 25290  2004   Athens  Aquatics   Swimming  Phelps, Michael     USA    Men
# 25329  2004   Athens  Aquatics   Swimming  Phelps, Michael     USA    Men
# 25365  2004   Athens  Aquatics   Swimming  Phelps, Michael     USA    Men
# 27228  2008  Beijing  Aquatics   Swimming  Phelps, Michael     USA    Men
# 27256  2008  Beijing  Aquatics   Swimming  Phelps, Michael     USA    Men
# ...     ...      ...       ...        ...              ...     ...    ...
# 27280  2008  Beijing  Aquatics   Swimming  Phelps, Michael     USA    Men
# ...

# %%
###Working with datatype

# %%
data.head()
# Out:
#   Survived  Class  Gender   Age  SipSp  ParCh     Fare Emb Deck
# 0        0      3    male  22.0      1      0     7.25   S  NaN
# 1        1      1  female  38.0      1      0  71.2833   C    C
# 2        1      3  female  26.0      0      0    7.925   S  NaN
# 3        1      1  female  35.0      1      0     53.1   S    C
# 4        0      3    male  35.0      0      0     8.05   S  NaN

# %%
data['Fare'] = data['Fare'].astype('float')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 894 entries, 0 to 893
# Data columns (total 9 columns):
# Survived    894 non-null object
# Class       894 non-null int64
# Gender      894 non-null object
# Age         758 non-null object
# SipSp       894 non-null int64
# ParCh       894 non-null int64
# Fare        894 non-null float64
# Emb         892 non-null object
# Deck        203 non-null object
# dtypes: float64(1), int64(3), object(5)
# memory usage: 62.9+ KB

# %%
data['Survived'] = data['Survived'].astype('int')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 894 entries, 0 to 893
# Data columns (total 9 columns):
# Survived    894 non-null int32
# Class       894 non-null int64
# Gender      894 non-null object
# Age         758 non-null object
# SipSp       894 non-null int64
# ParCh       894 non-null int64
# Fare        894 non-null float64
# Emb         892 non-null object
# Deck        203 non-null object
# dtypes: float64(1), int32(1), int64(3), object(4)
# memory usage: 59.4+ KB

# %%
###

# %%
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31170 entries, 0 to 31169
# Data columns (total 9 columns):
# Year            31170 non-null int64
# City            31170 non-null object
# Sport           31170 non-null object
# Discipline      31170 non-null object
# Athlete_name    31170 non-null object
# Country         31166 non-null object
# Gender          31170 non-null object
# Event           31170 non-null object
# Medal           31170 non-null object
# dtypes: int64(1), object(8)
# memory usage: 2.1+ MB

# %%
##detecting missing values

# %%
data.head(20)
# Out:
#     Survived  Class  Gender           Age  SipSp  ParCh     Fare Emb Deck
# 0          0      3    male          22.0      1      0   7.2500   S  NaN
# 1          1      1  female          38.0      1      0  71.2833   C    C
# 2          1      3  female          26.0      0      0   7.9250   S  NaN
# 3          1      1  female          35.0      1      0  53.1000   S    C
# 4          0      3    male          35.0      0      0   8.0500   S  NaN
# 5          0      3    male  Missing Data      0      0   8.4583   Q  NaN
# 6          0      1    male          54.0      0      0  51.8625   S    E
# 7          0      3    male           2.0      3      1  21.0750   S  NaN
# 8          1      3  female          27.0      0      2  11.1333   S  NaN
# 9          1      2  female          14.0      1      0  30.0708   C  NaN
# 10         1      3  female           4.0      1      1  16.7000   S    G
# 11         1      1  female          58.0      0      0  26.5500   S    C
# ...

# %%
data.isna() #return bolean
# Out:
#      Survived  Class  Gender    Age  SipSp  ParCh   Fare    Emb   Deck
# 0       False  False   False  False  False  False  False  False   True
# 1       False  False   False  False  False  False  False  False  False
# 2       False  False   False  False  False  False  False  False   True
# 3       False  False   False  False  False  False  False  False  False
# 4       False  False   False  False  False  False  False  False   True
# 5       False  False   False  False  False  False  False  False   True
# 6       False  False   False  False  False  False  False  False  False
# 7       False  False   False  False  False  False  False  False   True
# 8       False  False   False  False  False  False  False  False   True
# 9       False  False   False  False  False  False  False  False   True
# ..        ...    ...     ...    ...    ...    ...    ...    ...    ...
# 884     False  False   False  False  False  False  False  False   True
# ...

# %%
data.isna().sum(axis=0) #column to find out the total missing value
# Out:
# Survived      0
# Class         0
# Gender        0
# Age         136
# SipSp         0
# ParCh         0
# Fare          0
# Emb           2
# Deck        691
# dtype: int64

# %%
data.isna().any(axis=0)
# Out:
# Survived    False
# Class       False
# Gender      False
# Age          True
# SipSp       False
# ParCh       False
# Fare        False
# Emb          True
# Deck         True
# dtype: bool

# %%
data[data.isna().any(axis=1)] #only shows rows that has missing value
# Out:
#      Survived  Class  Gender           Age  SipSp  ParCh     Fare Emb Deck
# 0           0      3    male          22.0      1      0   7.2500   S  NaN
# 2           1      3  female          26.0      0      0   7.9250   S  NaN
# 4           0      3    male          35.0      0      0   8.0500   S  NaN
# 5           0      3    male  Missing Data      0      0   8.4583   Q  NaN
# 7           0      3    male           2.0      3      1  21.0750   S  NaN
# 8           1      3  female          27.0      0      2  11.1333   S  NaN
# 9           1      2  female          14.0      1      0  30.0708   C  NaN
# 12          0      3    male          20.0      0      0   8.0500   S  NaN
# 13          0      3    male          39.0      1      5  31.2750   S  NaN
# 14          0      3  female          14.0      0      0   7.8542   S  NaN
# ..        ...    ...     ...           ...    ...    ...      ...  ..  ...
# ...

# %%
#oposite of isna() .. notna()

# %%
data.notna()
# Out:
#      Survived  Class  Gender    Age  SipSp  ParCh  Fare   Emb   Deck
# 0        True   True    True   True   True   True  True  True  False
# 1        True   True    True   True   True   True  True  True   True
# 2        True   True    True   True   True   True  True  True  False
# 3        True   True    True   True   True   True  True  True   True
# 4        True   True    True   True   True   True  True  True  False
# 5        True   True    True   True   True   True  True  True  False
# 6        True   True    True   True   True   True  True  True   True
# 7        True   True    True   True   True   True  True  True  False
# 8        True   True    True   True   True   True  True  True  False
# 9        True   True    True   True   True   True  True  True  False
# ..        ...    ...     ...    ...    ...    ...   ...   ...    ...
# 884      True   True    True   True   True   True  True  True  False
# 885      True   True    True   True   True   True  True  True  False
# ...

# %%
data.notna().sum(axis=0)
# Out:
# Survived    894
# Class       894
# Gender      894
# Age         758
# SipSp       894
# ParCh       894
# Fare        894
# Emb         892
# Deck        203
# dtype: int64

# %%
#grphical way to find missing values

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
plt.figure(figsize=(12,8))
sns.heatmap(data.notna())
plt.show()

# %%
#drop missing values

# %%
data['Age'].value_counts(dropna=False)
# Out:
# NaN             136
# Missing Data     41
# 24.0             31
# 22.0             27
# 18.0             26
# 19.0             25
# 28.0             25
# 30.0             25
# 21.0             24
# 36.0             23
#                ...
# 34.5              1
# 80.0              1
# 102               1
# 14.5              1
# 20.5              1
# 55.5              1
# 23.5              1
# 250               1
# 36.5              1
# 0.67              1
# Name: Age, Length: 93, dtype: int64

# %%
#as there are some values name as ['Missing Data'] need to be changed before further cleaning

# %%
import numpy as np

# %%
data['Age'].replace(to_replace='Missing Data',value=np.nan, inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 894 entries, 0 to 893
# Data columns (total 9 columns):
# Survived    894 non-null int32
# Class       894 non-null int64
# Gender      894 non-null object
# Age         717 non-null object
# SipSp       894 non-null int64
# ParCh       894 non-null int64
# Fare        894 non-null float64
# Emb         892 non-null object
# Deck        203 non-null object
# dtypes: float64(1), int32(1), int64(3), object(4)
# memory usage: 59.4+ KB

# %%
data['Age'].value_counts(dropna=False)
# Out:
# NaN     177
# 24.0     31
# 22.0     27
# 18.0     26
# 19.0     25
# 28.0     25
# 30.0     25
# 21.0     24
# 36.0     23
# 25.0     22
#        ...
# 0.42      1
# 66.0      1
# 0.67      1
# 80.0      1
# 14.5      1
# 20.5      1
# 55.5      1
# 23.5      1
# 36.5      1
# 34.5      1
# Name: Age, Length: 92, dtype: int64

# %%
data['Age'] = data['Age'].astype('float')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 894 entries, 0 to 893
# Data columns (total 9 columns):
# Survived    894 non-null int32
# Class       894 non-null int64
# Gender      894 non-null object
# Age         717 non-null float64
# SipSp       894 non-null int64
# ParCh       894 non-null int64
# Fare        894 non-null float64
# Emb         892 non-null object
# Deck        203 non-null object
# dtypes: float64(2), int32(1), int64(3), object(3)
# memory usage: 59.4+ KB

# %%
####

# %%
new_data.head()
# Out:
#    Year    City     Sport Discipline        Athlete_name Country Gender  \
# 0  1896  Athens  Aquatics   Swimming       Hajos, Alfred     HUN    Men
# 1  1896  Athens  Aquatics   Swimming    Herschmann, Otto     AUT    Men
# 2  1896  Athens  Aquatics   Swimming   Drivas, Dimitrios     GRE    Men
# 3  1896  Athens  Aquatics   Swimming  Malokinis, Ioannis     GRE    Men
# 4  1896  Athens  Aquatics   Swimming  Chasapis, Spiridon     GRE    Men
#
#                         Event   Medal
# 0              100M Freestyle    Gold
# 1              100M Freestyle  Silver
# 2  100M Freestyle For Sailors  Bronze
# 3  100M Freestyle For Sailors    Gold
# 4  100M Freestyle For Sailors  Silver

# %%
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31170 entries, 0 to 31169
# Data columns (total 9 columns):
# Year            31170 non-null int64
# City            31170 non-null object
# Sport           31170 non-null object
# Discipline      31170 non-null object
# Athlete_name    31170 non-null object
# Country         31166 non-null object
# Gender          31170 non-null object
# Event           31170 non-null object
# Medal           31170 non-null object
# dtypes: int64(1), object(8)
# memory usage: 2.1+ MB

# %%
new_data[new_data.isna().any(axis=1)]
# Out:
#        Year    City          Sport           Discipline     Athlete_name  \
# 29608  2012  London      Athletics            Athletics          Pending
# 31077  2012  London  Weightlifting        Weightlifting          Pending
# 31096  2012  London  Weightlifting        Weightlifting          Pending
# 31115  2012  London      Wrestling  Wrestling Freestyle  Kudukhov, Besik
#
#       Country Gender     Event   Medal
# 29608     NaN  Women     1500M    Gold
# 31077     NaN  Women      63KG    Gold
# 31096     NaN    Men      94KG  Silver
# 31115     NaN    Men  Wf 60 KG  Silver

# %%
######
#removing missing values
#####

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 894 entries, 0 to 893
# Data columns (total 9 columns):
# Survived    894 non-null int32
# Class       894 non-null int64
# Gender      894 non-null object
# Age         717 non-null float64
# SipSp       894 non-null int64
# ParCh       894 non-null int64
# Fare        894 non-null float64
# Emb         892 non-null object
# Deck        203 non-null object
# dtypes: float64(2), int32(1), int64(3), object(3)
# memory usage: 59.4+ KB

# %%
#age,deck,and emb column

# %%
#Emb has 2 missing values

# %%
data[data['Emb'].isna()]
# Out:
#      Survived  Class  Gender   Age  SipSp  ParCh  Fare  Emb Deck
# 61          1      1  female  38.0      0      0  80.0  NaN    B
# 829         1      1  female  62.0      0      0  80.0  NaN    B

# %%
#For further data analysis data['Emb'] column may not be so useful.
#either the whole column can be droped or in that case just leave it like that

# %%
data['Age'].value_counts(dropna=False)
# Out:
# NaN        177
#  24.00      31
#  22.00      27
#  18.00      26
#  30.00      25
#  19.00      25
#  28.00      25
#  21.00      24
#  36.00      23
#  25.00      22
#           ...
#  53.00       1
#  66.00       1
#  55.50       1
#  23.50       1
#  20.50       1
#  102.00      1
#  490.00      1
#  14.50       1
#  12.00       1
#  0.42        1
# Name: Age, Length: 92, dtype: int64

# %%
data['Age'].mean(skipna=True) #pandas can default skip nan values
# Out:
# 30.718507670850766

# %%
data.shape
# Out:
# (894, 9)

# %%
data.dropna().shape #remove all rows wherever it finds missing values
# Out:
# (182, 9)

# %%
#it's not actually good here

# %%
data.dropna(axis=1,how='any').shape
# Out:
# (894, 6)

# %%
data.dropna(axis=0, thresh=8).shape #remove rows that has at least 8 missing values
# Out:
# (736, 9)

# %%
data.dropna(axis=1,thresh=500).shape
# Out:
# (894, 8)

# %%
#500 missing value meaning that column will be useless

# %%
data.dropna(axis=1,thresh=500,inplace=True)

# %%
data.head()
# Out:
#    Survived  Class  Gender   Age  SipSp  ParCh     Fare Emb
# 0         0      3    male  22.0      1      0   7.2500   S
# 1         1      1  female  38.0      1      0  71.2833   C
# 2         1      3  female  26.0      0      0   7.9250   S
# 3         1      1  female  35.0      1      0  53.1000   S
# 4         0      3    male  35.0      0      0   8.0500   S

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 894 entries, 0 to 893
# Data columns (total 8 columns):
# Survived    894 non-null int32
# Class       894 non-null int64
# Gender      894 non-null object
# Age         717 non-null float64
# SipSp       894 non-null int64
# ParCh       894 non-null int64
# Fare        894 non-null float64
# Emb         892 non-null object
# dtypes: float64(2), int32(1), int64(3), object(2)
# memory usage: 52.5+ KB

# %%
data.dropna(axis=0,subset=['Survived','Class','Gender','Age'], how='any').shape
# Out:
# (717, 8)

# %%
#####

# %%
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31170 entries, 0 to 31169
# Data columns (total 9 columns):
# Year            31170 non-null int64
# City            31170 non-null object
# Sport           31170 non-null object
# Discipline      31170 non-null object
# Athlete_name    31170 non-null object
# Country         31166 non-null object
# Gender          31170 non-null object
# Event           31170 non-null object
# Medal           31170 non-null object
# dtypes: int64(1), object(8)
# memory usage: 2.1+ MB

# %%
new_data[new_data.isna().any(axis=1)]
# Out:
#        Year    City          Sport           Discipline     Athlete_name  \
# 29608  2012  London      Athletics            Athletics          Pending
# 31077  2012  London  Weightlifting        Weightlifting          Pending
# 31096  2012  London  Weightlifting        Weightlifting          Pending
# 31115  2012  London      Wrestling  Wrestling Freestyle  Kudukhov, Besik
#
#       Country Gender     Event   Medal
# 29608     NaN  Women     1500M    Gold
# 31077     NaN  Women      63KG    Gold
# 31096     NaN    Men      94KG  Silver
# 31115     NaN    Men  Wf 60 KG  Silver

# %%
new_data.dropna(inplace=True)

# %%
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31166 entries, 0 to 31169
# Data columns (total 9 columns):
# Year            31166 non-null int64
# City            31166 non-null object
# Sport           31166 non-null object
# Discipline      31166 non-null object
# Athlete_name    31166 non-null object
# Country         31166 non-null object
# Gender          31166 non-null object
# Event           31166 non-null object
# Medal           31166 non-null object
# dtypes: int64(1), object(8)
# memory usage: 2.4+ MB

# %%
###########
#Replacing missing Values
###########

# %%
data.info() #deck column removed
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 894 entries, 0 to 893
# Data columns (total 8 columns):
# Survived    894 non-null int32
# Class       894 non-null int64
# Gender      894 non-null object
# Age         717 non-null float64
# SipSp       894 non-null int64
# ParCh       894 non-null int64
# Fare        894 non-null float64
# Emb         892 non-null object
# dtypes: float64(2), int32(1), int64(3), object(2)
# memory usage: 52.5+ KB

# %%
data['Age'].mean()
# Out:
# 30.718507670850766

# %%
mean = round(data['Age'].mean(),1)

# %%
mean
# Out:
# 30.7

# %%
data['Age'].fillna(mean,inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 894 entries, 0 to 893
# Data columns (total 8 columns):
# Survived    894 non-null int32
# Class       894 non-null int64
# Gender      894 non-null object
# Age         894 non-null float64
# SipSp       894 non-null int64
# ParCh       894 non-null int64
# Fare        894 non-null float64
# Emb         892 non-null object
# dtypes: float64(2), int32(1), int64(3), object(2)
# memory usage: 52.5+ KB

# %%
######################
## DETECTING MISSING VALUES
######################

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 894 entries, 0 to 893
# Data columns (total 8 columns):
# Survived    894 non-null int32
# Class       894 non-null int64
# Gender      894 non-null object
# Age         894 non-null float64
# SipSp       894 non-null int64
# ParCh       894 non-null int64
# Fare        894 non-null float64
# Emb         892 non-null object
# dtypes: float64(2), int32(1), int64(3), object(2)
# memory usage: 52.5+ KB

# %%
data.duplicated(keep='first')
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
#        ...
# 884     True
# 885    False
# 886     True
# 887    False
# 888    False
# 889    False
# 890    False
# 891     True
# 892     True
# 893     True
# Length: 894, dtype: bool

# %%
data.duplicated(keep='first').sum()
# Out:
# 114

# %%
data[data.duplicated(keep=False)]
# Out:
#      Survived  Class  Gender   Age  SipSp  ParCh     Fare Emb
# 4           0      3    male  35.0      0      0   8.0500   S
# 26          0      3    male  30.7      0      0   7.2250   C
# 28          1      3  female  30.7      0      0   7.8792   Q
# 29          0      3    male  30.7      0      0   7.8958   S
# 32          1      3  female  30.7      0      0   7.7500   Q
# 37          0      3    male  21.0      0      0   8.0500   S
# 42          0      3    male  30.7      0      0   7.8958   C
# 45          0      3    male  30.7      0      0   8.0500   S
# 46          0      3    male  30.7      1      0  15.5000   Q
# 47          1      3  female  30.7      0      0   7.7500   Q
# ..        ...    ...     ...   ...    ...    ...      ...  ..
# 859         0      3    male  30.7      0      0   7.2292   C
# 863         0      3  female  30.7      8      2  69.5500   S
# 870         0      3    male  26.0      0      0   7.8958   S
# ...

# %%
data.duplicated(keep='first',subset=['Survived','Class']).sum()
# Out:
# 888

# %%
########

# %%
new_data[new_data.duplicated(keep=False)]
# Out:
#        Year       City      Sport Discipline           Athlete_name Country  \
# 2068   1912  Stockholm  Athletics  Athletics  Lelong, Charles Louis     FRA
# 2069   1912  Stockholm  Athletics  Athletics  Lelong, Charles Louis     FRA
# 12252  1968     Mexico    Fencing    Fencing          Kalmar, Janos     HUN
# 12253  1968     Mexico    Fencing    Fencing          Kalmar, Janos     HUN
# 15595  1980     Moscow     Boxing     Boxing       Mustafov, Ismail     BUL
# 15596  1980     Moscow     Boxing     Boxing       Mustafov, Ismail     BUL
# 16101  1980     Moscow     Hockey     Hockey           Singh, Singh     IND
# 16102  1980     Moscow     Hockey     Hockey           Singh, Singh     IND
# 21832  1996    Atlanta   Baseball   Baseball         Scull, Antonio     CUB
# 21833  1996    Atlanta   Baseball   Baseball         Scull, Antonio     CUB
# 28677  2008    Beijing     Rowing     Rowing      Volpenhein, Bryan     USA
# ...

# %%
new_data.loc[(new_data['Sport']=='Basketball') & (new_data['Year']==2012)]
# Out:
#        Year    City       Sport  Discipline        Athlete_name Country  \
# 29801  2012  London  Basketball  Basketball    Anthony, Carmelo     USA
# 29802  2012  London  Basketball  Basketball        Bryant, Kobe     USA
# 29803  2012  London  Basketball  Basketball     Chandler, Tyson     USA
# 29804  2012  London  Basketball  Basketball      Davis, Anthony     USA
# 29805  2012  London  Basketball  Basketball       Durant, Kevin     USA
# 29806  2012  London  Basketball  Basketball       Harden, James     USA
# 29807  2012  London  Basketball  Basketball     Iguodala, Andre     USA
# 29808  2012  London  Basketball  Basketball       James, Lebron     USA
# 29809  2012  London  Basketball  Basketball         Love, Kevin     USA
# 29810  2012  London  Basketball  Basketball         Paul, Chris     USA
# ...     ...     ...         ...         ...                 ...     ...
# 29863  2012  London  Basketball  Basketball  Cambage, Elizabeth     AUS
# ...

# %%
##Removing Duplicate

# %%
data[data.duplicated()]
# Out:
#      Survived  Class  Gender   Age  SipSp  ParCh     Fare Emb
# 47          1      3  female  30.7      0      0   7.7500   Q
# 76          0      3    male  30.7      0      0   7.8958   S
# 77          0      3    male  30.7      0      0   8.0500   S
# 87          0      3    male  30.7      0      0   8.0500   S
# 95          0      3    male  30.7      0      0   8.0500   S
# 101         0      3    male  30.7      0      0   7.8958   S
# 121         0      3    male  30.7      0      0   8.0500   S
# 133         1      2  female  29.0      1      0  26.0000   S
# 173         0      3    male  21.0      0      0   7.9250   S
# 196         0      3    male  30.7      0      0   7.7500   Q
# ..        ...    ...     ...   ...    ...    ...      ...  ..
# 859         0      3    male  30.7      0      0   7.2292   C
# 863         0      3  female  30.7      8      2  69.5500   S
# 870         0      3    male  26.0      0      0   7.8958   S
# ...

# %%
 data.drop(index=[891,892,893],inplace=True)

# %%
data.tail()
# Out:
#      Survived  Class  Gender   Age  SipSp  ParCh   Fare Emb
# 886         0      2    male  27.0      0      0  13.00   S
# 887         1      1  female  19.0      0      0  30.00   S
# 888         0      3  female  30.7      1      2  23.45   S
# 889         1      1    male  26.0      0      0  30.00   C
# 890         0      3    male  32.0      0      0   7.75   Q

# %%
#####
new_data[new_data.duplicated(keep=False)]
# Out:
#        Year       City      Sport Discipline           Athlete_name Country  \
# 2068   1912  Stockholm  Athletics  Athletics  Lelong, Charles Louis     FRA
# 2069   1912  Stockholm  Athletics  Athletics  Lelong, Charles Louis     FRA
# 12252  1968     Mexico    Fencing    Fencing          Kalmar, Janos     HUN
# 12253  1968     Mexico    Fencing    Fencing          Kalmar, Janos     HUN
# 15595  1980     Moscow     Boxing     Boxing       Mustafov, Ismail     BUL
# 15596  1980     Moscow     Boxing     Boxing       Mustafov, Ismail     BUL
# 16101  1980     Moscow     Hockey     Hockey           Singh, Singh     IND
# 16102  1980     Moscow     Hockey     Hockey           Singh, Singh     IND
# 21832  1996    Atlanta   Baseball   Baseball         Scull, Antonio     CUB
# 21833  1996    Atlanta   Baseball   Baseball         Scull, Antonio     CUB
# 28677  2008    Beijing     Rowing     Rowing      Volpenhein, Bryan     USA
# ...

# %%
new_data.drop(index=[2069,12253,15596,21833,28678], inplace=True)

# %%
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31161 entries, 0 to 31169
# Data columns (total 9 columns):
# Year            31161 non-null int64
# City            31161 non-null object
# Sport           31161 non-null object
# Discipline      31161 non-null object
# Athlete_name    31161 non-null object
# Country         31161 non-null object
# Gender          31161 non-null object
# Event           31161 non-null object
# Medal           31161 non-null object
# dtypes: int64(1), object(8)
# memory usage: 2.4+ MB

# %%
####saving data

# %%
data.head()
# Out:
#    Survived  Class  Gender   Age  SipSp  ParCh     Fare Emb
# 0         0      3    male  22.0      1      0   7.2500   S
# 1         1      1  female  38.0      1      0  71.2833   C
# 2         1      3  female  26.0      0      0   7.9250   S
# 3         1      1  female  35.0      1      0  53.1000   S
# 4         0      3    male  35.0      0      0   8.0500   S

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 0 to 890
# Data columns (total 8 columns):
# Survived    891 non-null int32
# Class       891 non-null int64
# Gender      891 non-null object
# Age         891 non-null float64
# SipSp       891 non-null int64
# ParCh       891 non-null int64
# Fare        891 non-null float64
# Emb         889 non-null object
# dtypes: float64(2), int32(1), int64(3), object(2)
# memory usage: 59.2+ KB

# %%
data.to_csv('titanic_new.csv',index=False)

# %%
t_data = pd.read_csv('titanic_new.csv')

# %%
t_data.head()
# Out:
#    Survived  Class  Gender   Age  SipSp  ParCh     Fare Emb
# 0         0      3    male  22.0      1      0   7.2500   S
# 1         1      1  female  38.0      1      0  71.2833   C
# 2         1      3  female  26.0      0      0   7.9250   S
# 3         1      1  female  35.0      1      0  53.1000   S
# 4         0      3    male  35.0      0      0   8.0500   S

# %%
new_data.to_csv('summer_new.csv',index=False)

# %%
new_data_s = pd.read_csv('summer_new.csv')

# %%
new_data_s.head()
# Out:
#    Year    City     Sport Discipline        Athlete_name Country Gender  \
# 0  1896  Athens  Aquatics   Swimming       Hajos, Alfred     HUN    Men
# 1  1896  Athens  Aquatics   Swimming    Herschmann, Otto     AUT    Men
# 2  1896  Athens  Aquatics   Swimming   Drivas, Dimitrios     GRE    Men
# 3  1896  Athens  Aquatics   Swimming  Malokinis, Ioannis     GRE    Men
# 4  1896  Athens  Aquatics   Swimming  Chasapis, Spiridon     GRE    Men
#
#                         Event   Medal
# 0              100M Freestyle    Gold
# 1              100M Freestyle  Silver
# 2  100M Freestyle For Sailors  Bronze
# 3  100M Freestyle For Sailors    Gold
# 4  100M Freestyle For Sailors  Silver
